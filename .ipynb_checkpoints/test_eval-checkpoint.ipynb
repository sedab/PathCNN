# %% [markdown]
# # evaluation functions

# %%
#libraries
import matplotlib
matplotlib.use('Agg')
#import torch
import numpy as np
from sklearn.metrics import roc_curve, auc, roc_auc_score, cohen_kappa_score, jaccard_similarity_score, log_loss,recall_score, precision_score
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from PIL import Image
from utils.eval import *
from utils.dataloader import *
import os
from itertools import chain

# %matplotlib inline
# Out:
# /gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-fadc27d6d18e>", line 17, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
experiments = '/gpfs/scratch/bilals01/test-repo/experiments/'
log_file = '/gpfs/scratch/bilals01/test-repo/logs/exp6_train.log'

#exp_name = 'exp_nicolas'
exp_name = 'exp2'
num_class = 3
#pred_label = 'pred_label_avg_601_0exp_epoch_3.pth.npy'
pred_label = 'test_pred_label_max_epoch_24.pth.npy'
#pred_label = 'test_pred_label_max_epoch_17.pth.npy'

class_names, class_codes, class_coding = get_class_coding(log_file)
print(class_codes)
print(class_coding)
# Out:
# {0: 'Solid_Tissue_Normal', 1: 'LUAD', 2: 'LUSC'}

# %%
# Out:
# [0, 1, 2]

# %%
os.chdir(experiments + exp_name+ '/outputs/') #input
pd = np.load(open(pred_label, 'rb'))
predictions = pd[:,1:num_class+1] 
labels = pd[:,num_class+1]
predictions = np.asarray([[float(j) for j in i] for i in predictions])
labels = np.asarray([float(i) for i in labels])

# %%
#output 
#tpr; true positive rate
#fpr; false positive rate
#roc_auc; main eval metrics
#cu; upper confidence interval
#cl; lower confidence interval
fpr, tpr, roc_auc, cu, cl = get_auc(predictions, labels, class_names, class_codes)

os.chdir(experiments+exp_name+'/outputs/')
plt.savefig(pred_label[:-8]+'.png', dpi=500, bbox_inches = 'tight')

#create a data frame
results = {}
[class_coding,roc_auc,cu,cl ]
results['class_coding'] = class_coding
results['eval_metrics'] = roc_auc
results['cu'] = cu
results['c'] = cl
results

#write to json
import json
with open(pred_label[:-8]+'_results.json', 'w') as outfile:
    json.dump(results, outfile)

#write true positive and false positive rates if needed
#import pickle
#filehandler = open(b"tpr_fpr.pkl","wb")
#pickle.dump([tpr,fpr],filehandler)
#filehandler.close()
# Out:
# AUC:
# {0: 0.9853010765408732, 1: 0.9486931986931987, 2: 0.9260858456821666, 'micro': 0.9518951880627614, 'macro': 0.9545224783295329, 'precision': 0.8594472672790046, 'recall': 0.862869382839888, 'cohenskappa': 0.7741969383823168, 'jaccard': 0.8498293515358362, 'logloss': 0.5361398209139285}
# CU:
# {0: 0.9988888888888888, 1: 0.967817304793488, 2: 0.9500301477238469, 'micro': 0.9632089933571796, 'macro': 0.997756487994179}
# CL:
# {0: 0.9599096083026447, 1: 0.928395441946412, 2: 0.8988738738738739, 'micro': 0.9392252234457558, 'macro': 0.9098597359735973}
