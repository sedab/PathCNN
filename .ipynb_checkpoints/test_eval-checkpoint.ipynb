# %% [markdown]
# # evaluation functions

# %%
#libraries
import matplotlib
matplotlib.use('Agg')
#import torch
import numpy as np
from sklearn.metrics import roc_curve, auc, roc_auc_score, cohen_kappa_score, jaccard_similarity_score, log_loss,recall_score, precision_score
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from PIL import Image
from utils.eval import *
from utils.dataloader import *
import os
from itertools import chain
import os.path
import json




# %matplotlib inline

# %% [markdown]
# ## evaluate single output file

# %%
experiments = '/scratch/sb3923/experiments/'
log_file = '/scratch/sb3923/logs/lung_5x_pathcnn_6layers_tr.log'


num_class = 3


# Path to be created
#os.mkdir( experiments + exp_name+ '/outputs/results/' );

pred_label = 'val_pred_label_avg_epoch_4.npy'

class_names, class_codes, class_coding = get_class_coding(log_file)
print(class_codes)
print(class_coding)

# %%
os.chdir(experiments + exp_name+ '/outputs/') #input
pd = np.load(open(pred_label, 'rb'))
predictions = pd[:,1:num_class+1] 
labels = pd[:,num_class+1]
predictions = np.asarray([[float(j) for j in i] for i in predictions])
labels = np.asarray([float(i) for i in labels])

# %%
#output 
#tpr; true positive rate
#fpr; false positive rate
#roc_auc; main eval metrics
#cu; upper confidence interval
#cl; lower confidence interval
fpr, tpr, roc_auc, cu, cl = get_auc(predictions, labels, class_names, class_codes)

os.chdir(experiments+exp_name+'/outputs/')
plt.savefig(pred_label[:-8]+'.png', dpi=500, bbox_inches = 'tight')

#create a data frame
results = {}
[class_coding,roc_auc,cu,cl ]
results['class_coding'] = class_coding
results['eval_metrics'] = roc_auc
results['cu'] = cu
results['cl'] = cl
results

#write to json
import json
with open(pred_label[:-8]+'_results.json', 'w') as outfile:
    json.dump(results, outfile)

#write true positive and false positive rates if needed
#import pickle
#filehandler = open(b"tpr_fpr.pkl","wb")
#pickle.dump([tpr,fpr],filehandler)
#filehandler.close()

# %% [markdown]
# ## evaluating multiple files

# %%
#not os.path.exists(experiments + exp_name+ '/outputs/results/')

# %%
#exp_name = "kidney_alexnet_tr"
#exp_name = "kidney_vgg16_tr"
#exp_name = "lung_7layers_tr"
#exp_name = "lung_512_pathcnn_6layers_tr"
exp_name = "lung_vgg16_tr"
#exp_name = "lung_alexnet_tr"

experiments = '/scratch/sb3923/experiments/'
log_file = '/scratch/sb3923/logs/'+exp_name+'.log'

num_class = 3

# Path to be created
if not os.path.exists(experiments + exp_name+ '/outputs/results/'):
    os.mkdir( experiments + exp_name+ '/outputs/results/');

class_names, class_codes, class_coding = get_class_coding(log_file)
print(class_codes)
print(class_coding)

# %%
#exp_names=['ds3_3layers_tr','ds3_4layers_tr','ds3_5layers_tr', 'ds3_6layers_tr','ds3_7layers_tr','ds3_8layers_tr']

#exp_names=['lung_ds1_3layers_tr','lung_ds1_4layers_tr','lung_ds1_5layers_tr','lung_ds1_6layers_tr',
#           'lung_ds1_7layers_tr','lung_ds1_8layers_tr','lung_ds1_alexnet_tr']

#exp_names=['lung_ds2_3layers_tr','lung_ds2_4layers_tr','lung_ds2_5layers_tr','lung_ds2_6layers_tr',
#           'lung_ds2_7layers_tr','lung_ds2_8layers_tr','lung_ds2_alexnet_tr']


#exp_names=['lung_3layers_tr','lung_4layers_tr','lung_512_pathcnn_6layers_tr','lung_5layers_tr',
#'lung_5x_pathcnn_6layers_tr','lung_7layers_tr','lung_8layers_tr','lung_alexnet_tr',
#           'lung_pathcnn_6layers_tr','lung_resnet18_tr','lung_vgg16_tr']


#exp_names=['lung_ds1_resnet18_tr','lung_ds1_vgg16_tr','lung_ds2_resnet18_tr',
#           'lung_ds2_vgg16_tr','lung_ds3_alexnet_tr','lung_ds3_resnet18_tr',
#           'lung_ds3_vgg16_tr']


#exp_names=['breast_resnet18_tr',
#  'breast_subtypes_pathcnn_6layers_tr','breast_vgg16_tr','breast_3layers_tr','breast_4layers_tr','breast_5layers_tr','breast_6layers_tr',
#   'breast_7layers_tr','breast_8layers_tr','breast_alexnet_tr']


#exp_names=['kidney_alexnet_tr','kidney_resnet18_tr','kidney_vgg16_tr','kidney_3layers_tr',
#'kidney_4layers_tr','kidney_5layers_tr','kidney_6layers_tr','kidney_7layers_tr',
#'kidney_8layers_tr']

#exp_names=['breast_inceptionv3_tr']
#exp_names=['kidney_inceptionv3_tr']
#exp_names=['lung_ds1_inceptionv3_tr','lung_ds2_inceptionv3_tr','lung_ds3_inceptionv3_tr',
#'lung_inceptionv3_tr','lung_ds1_resnet18_tr']

#exp_names=['breast_sub_basal_vs_all_and_normal_inceptionv3_tr','breast_sub_basal_vs_all_and_normal_vgg16_tr',
#           'breast_sub_basal_vs_all_and_normal_alexnet_tr','breast_sub_basal_vs_all_and_normal_resnet18_tr',
#           'breast_sub_basal_vs_all_and_normal_3layers_tr','breast_sub_basal_vs_all_and_normal_4layers_tr',
#           'breast_sub_basal_vs_all_and_normal_5layers_tr','breast_sub_basal_vs_all_and_normal_6layers_tr',
#           'breast_sub_basal_vs_all_and_normal_7layers_tr','breast_sub_basal_vs_all_and_normal_8layers_tr']

6layers
exp_names=['breast_sub_basal_vs_alltypes_no_normal_inceptionv3_tr','breast_sub_basal_vs_alltypes_no_normal_vgg16_tr',
           'breast_sub_basal_vs_alltypes_no_normal_alexnet_tr','breast_sub_basal_vs_alltypes_no_normal_resnet18_tr',
           'breast_sub_basal_vs_alltypes_no_normal_3layers_tr','breast_sub_basal_vs_alltypes_no_normal_4layers_tr',
           'breast_sub_basal_vs_alltypes_no_normal_5layers_tr','breast_sub_basal_vs_alltypes_no_normal_6layers_tr',
           'breast_sub_basal_vs_alltypes_no_normal_7layers_tr','breast_sub_basal_vs_alltypes_no_normal_8layers_tr']


#exp_names=['breast_sub_basal_vs_all_inceptionv3_tr','breast_sub_basal_vs_all_vgg16_tr',
#           'breast_sub_basal_vs_all_alexnet_tr','breast_sub_basal_vs_all_resnet18_tr',
#           'breast_sub_basal_vs_all_3layers_tr','breast_sub_basal_vs_all_4layers_tr',
#           'breast_sub_basal_vs_all_5layers_tr','breast_sub_basal_vs_all_6layers_tr',
#           'breast_sub_basal_vs_all_7layers_tr','breast_sub_basal_vs_all_8layers_tr']


num_class = 4
for exp_name in exp_names:
    experiments = '/scratch/sb3923/experiments/'
    log_file = '/scratch/sb3923/logs/'+exp_name+'.log'
    if not os.path.exists(experiments + exp_name+ '/outputs/results/'):
        os.mkdir( experiments + exp_name+ '/outputs/results/');

    class_names, class_codes, class_coding = get_class_coding(log_file)
    
    import glob
    path = experiments + exp_name+ '/outputs/'
    files = [f for f in glob.glob(path + "**/*.npy", recursive=True)]

    for f in files:
        ff = f.split('/')[-1].split('.')[0]
        print(f)
        os.chdir(experiments + exp_name+ '/outputs/') #input
        pd = np.load(open(f, 'rb'))
        predictions = pd[:,1:num_class+1] 
        labels = pd[:,num_class+1]
        predictions = np.asarray([[float(j) for j in i] for i in predictions])
        labels = np.asarray([float(i) for i in labels])


        fpr, tpr, roc_auc, cu, cl = get_auc(predictions, labels, class_names, class_codes)

        os.chdir(experiments+exp_name+'/outputs/results/')
        #plt.savefig(pred_label[:-8]+'.png', dpi=500, bbox_inches = 'tight')

        #create a data frame
        results = {}
        [class_coding,roc_auc,cu,cl ]
        results['class_coding'] = class_coding
        results['eval_metrics'] = roc_auc
        results['cu'] = cu
        results['cl'] = cl
        results

        #write to json
        with open(ff+'_results.json', 'w') as outfile:
            json.dump(results, outfile)
# Out:
# /scratch/sb3923/experiments/breast_sub_basal_vs_alltypes_no_normal_inceptionv3_tr/outputs/test_pred_label_max_epoch_20.pth.npy
# AUC:
# {0: 0.76632785467128028, 1: 0.65733333333333333, 2: 0.79691228070175446, 3: 0.57411608999810926, 'micro': 0.7566839677047289, 'logloss': 2.3380174129947378, 'cohenskappa': 0.33198903882942965, 'macro': 0.7025968184692829, 'jaccard': 0.55294117647058827, 'recall': 0.43304519368723099, 'precision': 0.40587944664031622}
# CU:
# {0: 0.84812912692589881, 1: 0.76144688644688652, 2: 0.85472222222222216, 3: 0.66334991708126045, 'micro': 0.79283424671698888, 'macro': 0.83957894736842109}
# CL:
# {0: 0.68598679383712391, 1: 0.56104186641099385, 2: 0.73828571428571421, 3: 0.48586309523809523, 'micro': 0.71901588201928535, 'macro': 0.52363395726980533}
# /scratch/sb3923/experiments/breast_sub_basal_vs_alltypes_no_normal_inceptionv3_tr/outputs/test_pred_label_max_epoch_7.pth.npy
# AUC:
# ...

# %% [markdown]
# ## aggregate jsons

# %%
#aggregate to a dataframe
import glob
import pandas as pd
all_results = pd.DataFrame()


#exp_names = ['lung_5x_pathcnn_6layers_tr',"lung_4layers_tr","lung_5layers_tr","lung_5x_pathcnn_6layers_tr",
#"lung_alexnet_tr","lung_pathcnn_6layers_tr","lung_resnet18_tr","lung_8layers_tr",
#"lung_3layers_tr","lung_7layers_tr","lung_512_pathcnn_6layers_tr"]
#class_nums = [3,3,3,3,3,3,3,3,3,3,3]

#exp_names = ["breast_subtypes_pathcnn_6layers_tr"]
#class_nums = [5]


#exp_names = ['breast_alexnet_tr',"breast_resnet18_tr","breast_vgg16_tr"]
#class_nums = [2,2,2]

#exp_names = ['kidney_alexnet_tr',"kidney_resnet18_tr","kidney_vgg16_tr"]
#class_nums = [4,4,4]

#exp_names=['ds3_3layers_tr','ds3_4layers_tr','ds3_5layers_tr', 'ds3_6layers_tr','ds3_7layers_tr','ds3_8layers_tr']
#class_nums = [3,3,3,3,3,3]


#exp_names=['lung_ds1_3layers_tr','lung_ds1_4layers_tr','lung_ds1_5layers_tr','lung_ds1_6layers_tr',
#           'lung_ds1_7layers_tr','lung_ds1_8layers_tr','lung_ds1_alexnet_tr']
#class_nums = [3,3,3,3,3,3,3]



#exp_names=['lung_ds2_3layers_tr','lung_ds2_4layers_tr','lung_ds2_5layers_tr','lung_ds2_6layers_tr',
#           'lung_ds2_7layers_tr','lung_ds2_8layers_tr','lung_ds2_alexnet_tr']
#class_nums = [3,3,3,3,3,3,3]


#exp_names=['lung_3layers_tr','lung_4layers_tr','lung_512_pathcnn_6layers_tr','lung_5layers_tr',
#'lung_5x_pathcnn_6layers_tr','lung_7layers_tr','lung_8layers_tr','lung_alexnet_tr',
#           'lung_pathcnn_6layers_tr','lung_resnet18_tr','lung_vgg16_tr']
#class_nums = [3,3,3,3,3,3,3,3,3,3,3]


#exp_names=['lung_ds1_resnet18_tr','lung_ds1_vgg16_tr','lung_ds2_resnet18_tr',
#           'lung_ds2_vgg16_tr','lung_ds3_alexnet_tr','lung_ds3_resnet18_tr',
#           'lung_ds3_vgg16_tr']
#class_nums = [3,3,3,3,3,3,3]


#exp_names=['breast_resnet18_tr',
#  'breast_subtypes_pathcnn_6layers_tr','breast_vgg16_tr','breast_3layers_tr','breast_4layers_tr','breast_5layers_tr','breast_6layers_tr',
#   'breast_7layers_tr','breast_8layers_tr','breast_alexnet_tr']
#class_nums = [2,2,2,2,2,2,2,2,2,2]


#exp_names=['kidney_alexnet_tr','kidney_resnet18_tr','kidney_vgg16_tr','kidney_3layers_tr',
#'kidney_4layers_tr','kidney_5layers_tr','kidney_6layers_tr','kidney_7layers_tr',
#'kidney_8layers_tr']
#class_nums = [4,4,4,4,4,4,4,4,4]



#exp_names=['breast_inceptionv3_tr']
#class_nums = [2]

#exp_names=['kidney_inceptionv3_tr']
#class_nums = [4]

#exp_names=['lung_ds1_inceptionv3_tr','lung_ds2_inceptionv3_tr','lung_ds3_inceptionv3_tr',
#'lung_inceptionv3_tr','lung_ds1_resnet18_tr']
#class_nums = [3,3,3,3,3]

exp_names=['breast_sub_basal_vs_all_and_normal_inceptionv3_tr','breast_sub_basal_vs_all_and_normal_vgg16_tr',
           'breast_sub_basal_vs_all_and_normal_alexnet_tr','breast_sub_basal_vs_all_and_normal_resnet18_tr',
           'breast_sub_basal_vs_all_and_normal_3layers_tr','breast_sub_basal_vs_all_and_normal_4layers_tr',
           'breast_sub_basal_vs_all_and_normal_5layers_tr','breast_sub_basal_vs_all_and_normal_6layers_tr',
           'breast_sub_basal_vs_all_and_normal_7layers_tr','breast_sub_basal_vs_all_and_normal_8layers_tr']

class_nums = [2,2,2,2,2,2,2,2,2,2]

#exp_names=['breast_sub_basal_vs_alltypes_no_normal_inceptionv3_tr','breast_sub_basal_vs_alltypes_no_normal_vgg16_tr',
#           'breast_sub_basal_vs_alltypes_no_normal_alexnet_tr','breast_sub_basal_vs_alltypes_no_normal_resnet18_tr',
#           'breast_sub_basal_vs_alltypes_no_normal_3layers_tr','breast_sub_basal_vs_alltypes_no_normal_4layers_tr',
#           'breast_sub_basal_vs_alltypes_no_normal_5layers_tr','breast_sub_basal_vs_alltypes_no_normal_6layers_tr',
#           'breast_sub_basal_vs_alltypes_no_normal_7layers_tr','breast_sub_basal_vs_alltypes_no_normal_8layers_tr']

#class_nums = [4,4,4,4,4,4,4,4,4,4]


#exp_names=['breast_sub_basal_vs_all_inceptionv3_tr','breast_sub_basal_vs_all_vgg16_tr',
#           'breast_sub_basal_vs_all_alexnet_tr','breast_sub_basal_vs_all_resnet18_tr',
#           'breast_sub_basal_vs_all_3layers_tr','breast_sub_basal_vs_all_4layers_tr',
#           'breast_sub_basal_vs_all_5layers_tr','breast_sub_basal_vs_all_6layers_tr',
#           'breast_sub_basal_vs_all_7layers_tr','breast_sub_basal_vs_all_8layers_tr']

#class_nums = [2,2,2,2,2,2,2,2,2,2]



test_valid = 'valid'
experiments = '/scratch/sb3923/experiments/'


i=0
for exp_name in exp_names: 
    
    num_class = class_nums[i]
    log_file = '/scratch/sb3923/logs/'+exp_name+'.log'
    class_names, class_codes, class_coding = get_class_coding(log_file)
    print(class_coding)


    path = experiments+exp_name+'/outputs/results/'
    res_files = [f for f in glob.glob(path + "**/*.json", recursive=True)]

    all_results['auc_'+class_coding[0]] = np.nan
    all_results['auc_'+class_coding[1]] = np.nan
    all_results['cu_'+class_coding[0]] = np.nan
    all_results['cl_'+class_coding[0]] = np.nan
    all_results['auc_micro'] = np.nan
    all_results['auc_macro'] = np.nan

    all_results['auc_precision'] = np.nan
    all_results['auc_recall'] = np.nan
    all_results['auc_cohenskappa'] = np.nan
    all_results['auc_jaccard'] = np.nan
    
    
    all_results['epoch']= np.nan

    if(num_class>2):
        all_results['auc_'+class_coding[2]] = np.nan
        all_results['cu_'+class_coding[2]] = np.nan
        all_results['cl_'+class_coding[2]] = np.nan
        all_results['cu_micro'] = np.nan
        all_results['cu_macro'] = np.nan
        all_results['cl_micro'] = np.nan
        all_results['cl_macro'] = np.nan   
        all_results['cu_'+class_coding[1]] = np.nan
        all_results['cl_'+class_coding[1]] = np.nan
    if(num_class>3):
        all_results['auc_'+class_coding[3]] = np.nan
        all_results['cu_'+class_coding[3]] = np.nan
        all_results['cl_'+class_coding[3]] = np.nan
    if(num_class>4):   
        all_results['auc_'+class_coding[4]] = np.nan
        all_results['cu_'+class_coding[4]] = np.nan
        all_results['cl_'+class_coding[4]] = np.nan

    ind=0
    for rf in res_files:
        if rf.split('/')[-1].startswith(test_valid) & rf.split('/')[-1].split('_')[3].startswith('avg'):
            print(rf)
            print(ind)
            with open(rf) as json_file:
                data = json.load(json_file)
                epoch = rf.split('_')[-2]
                all_results.loc[ind, 'epoch'] = int(epoch)
                all_results['auc_'+class_coding[0]].loc[ind]=data['eval_metrics']['0']
                all_results['auc_'+class_coding[1]].loc[ind]=data['eval_metrics']['1']
                all_results['auc_micro'].loc[ind]=data['eval_metrics']['micro']
                all_results['auc_macro'].loc[ind]=data['eval_metrics']['macro']
                all_results['auc_precision'].loc[ind]=data['eval_metrics']['precision']
                all_results['auc_recall'].loc[ind]=data['eval_metrics']['recall']
                all_results['auc_cohenskappa'].loc[ind]=data['eval_metrics']['cohenskappa']
                all_results['auc_jaccard'].loc[ind]=data['eval_metrics']['jaccard']
                all_results['cu_'+class_coding[0]].loc[ind]=data['cu']['0']
                all_results['cl_'+class_coding[0]].loc[ind]=data['cl']['0']

                if(num_class>2):
                    all_results['cu_micro'].loc[ind]=data['cu']['micro']
                    all_results['cu_macro'].loc[ind]=data['cu']['macro']
                    all_results['cl_micro'].loc[ind]=data['cl']['micro']
                    all_results['cl_macro'].loc[ind]=data['cl']['macro']
                    all_results['cu_'+class_coding[1]].loc[ind]=data['cu']['1']
                    all_results['cl_'+class_coding[1]].loc[ind]=data['cl']['1']
                    all_results['auc_'+class_coding[2]].loc[ind]=data['eval_metrics']['2']
                    all_results['cu_'+class_coding[2]].loc[ind]=data['cu']['2']
                    all_results['cl_'+class_coding[2]].loc[ind]=data['cl']['2']
                if(num_class>3):
                    all_results['auc_'+class_coding[3]].loc[ind]=data['eval_metrics']['3']
                    all_results['cu_'+class_coding[3]].loc[ind]=data['cu']['3']
                    all_results['cl_'+class_coding[3]].loc[ind]=data['cl']['3']
                if(num_class>4):  
                    all_results['auc_'+class_coding[4]].loc[ind]=data['eval_metrics']['4']
                    all_results['cu_'+class_coding[4]].loc[ind]=data['cu']['4']
                    all_results['cl_'+class_coding[4]].loc[ind]=data['cl']['4']

                ind=ind+1

    all_results=all_results.sort_values(by='epoch', ascending=True)

    #write the results into a csv
    os.chdir('/scratch/sb3923/experiments/all_results/')
    all_results.to_csv(exp_name+'_'+test_valid+'.csv')
    i=i+1

# %%
all_results

# %% [markdown]
# # for plotting

# %%
#os.chdir(experiments+exp_name+'/outputs/results/')
path = experiments+exp_name+'/outputs/results/'
res_files = [f for f in glob.glob(path + "**/*.json", recursive=True)]


macro = {}
LUSC = {}
LUAD = {}
normal = {}
#basal = {}
#her2 = {}
#luma = {}
#lumb = {}
#normal = {}
#0: 'Basal', 1: 'Her2', 2: 'LumA', 3: 'LumB', 4: 'Normal

for rf in res_files:
    print(rf)
    if rf.split('/')[-1].startswith('valid'):
        with open(rf) as json_file:
            data = json.load(json_file)
            epoch = rf.split('_')[-2]
            macro[epoch] = data['eval_metrics']['macro']
            #basal[epoch] = data['eval_metrics']['0']
            #her2[epoch] = data['eval_metrics']['1']
            #luma[epoch] = data['eval_metrics']['2']
            #lumb[epoch] = data['eval_metrics']['3']
            #normal[epoch] = data['eval_metrics']['4']
            LUSC[epoch] = data['eval_metrics']['2']
            LUAD[epoch] = data['eval_metrics']['1']
            normal[epoch] = data['eval_metrics']['0']
            #print(data['eval_metrics']['0'])
            #print(data['eval_metrics']['1'])
            #print(data['eval_metrics']['2'])
            #print(data['eval_metrics']['micro'])
            #print(data['eval_metrics']['macro'])
            #print(data['eval_metrics']['precision'])
            #print(data['eval_metrics']['recall'])
            #print(data['eval_metrics']['cohenskappa'])
            #print(data['eval_metrics']['jaccard'])
            #print('______________________________')
            #print(data['cu']['0'])
            #print(data['cu']['1'])
            #print(data['cu']['2'])
            #print(data['cu']['micro'])
            #print(data['cu']['macro'])
            #print('______________________________')
            #print(data['cl']['0'])
            #print(data['cl']['1'])
            #print(data['cl']['2'])
            #print(data['cl']['micro'])
            #print(data['cl']['macro'])

# %% [markdown]
# # plot

# %%
import matplotlib.pylab as plt

lists = sorted(macro.items()) # sorted by key, return a list of tuples
x, y = zip(*lists) # unpack a list of pairs into two tuples
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.title(exp_name+'_valid', fontsize=24)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('epoch', fontsize=24)
plt.ylabel('macro AUC', fontsize=24)
plt.rcParams['axes.linewidth'] = 0.5

plt.show()
