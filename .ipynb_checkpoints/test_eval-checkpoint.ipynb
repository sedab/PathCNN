# %% [markdown]
# # evaluation functions

# %%
#libraries
import matplotlib
matplotlib.use('Agg')
import torch
import numpy as np
from sklearn.metrics import roc_curve, auc, roc_auc_score, cohen_kappa_score, jaccard_similarity_score, log_loss,recall_score, precision_score
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from PIL import Image
from utils.eval import *
import os
# %matplotlib inline

# %%
root = '/gpfs/data/abl/deepomics/tsirigoslab/histopathology/Repos/deep-cancer/'
experiment = 'train_lung2'
pred_label_ = 'pred_label_avg_train_lung2_epoch_10.pth_ffpe.npy'
num_class = 3 #input
o_class='ffpe'

# %%
#get the train log file

new_model=experiment
infile = root+"logs/"+experiment+".log"
print(infile)

auc_new = []
phrase = "Class encoding:"


with open(infile, 'r+') as f:
    lines = f.readlines()
    for i in range(0, len(lines)):
        line = lines[i]
        #print(line)
        if phrase in line:
            class_encoding = lines[i + 1] # you may want to check that i < len(lines)
            break
# Out:
# /gpfs/data/abl/deepomics/tsirigoslab/histopathology/Repos/deep-cancer/logs/train_lung2.log

# %%
class_encoding = class_encoding.strip('\n').strip('{').strip('}')
class_names = []
class_codes = []

for c in class_encoding.split(','):
    print(c)
    class_names.append(c.split(':')[0].replace("'", "").replace(" ", "").split('-')[-1])
    class_codes.append(int(c.split(':')[1]))
    
#class_names = sorted(class_names)
#class_codes = sorted(class_codes)


class_coding = {}
for i in range(len(class_names)):
    class_coding[class_codes[i]] = class_names[i]

print(class_coding)
# Out:
# 'Solid_Tissue_Normal': 0
#  'TCGA-LUAD': 1
#  'TCGA-LUSC': 2
# {0: 'Solid_Tissue_Normal', 1: 'LUAD', 2: 'LUSC'}

# %%
root+'/experiments/'+experiment+'/'+o_class
# Out:
# '/gpfs/data/abl/deepomics/tsirigoslab/histopathology/Repos/deep-cancer//experiments/train_lung2/ffpe'

# %%
os.chdir(root+'/experiments/'+experiment+'/'+o_class) #input

# %%
pred_label = np.load(open(pred_label_, 'rb'))
#print(pred_label)
predictions = pred_label[:,:num_class]
labels = pred_label[:,num_class] 

#columns: 0 class, 1 class, 2 class, labels

# %%
labels = labels[0:-1] 
predictions = predictions[0:-1] 
type(labels[0])
# Out:
# numpy.float64

# %%
len(labels)
# Out:
# 140

# %%
roc = get_auc(predictions, labels, class_names, class_codes)
#set current dir
os.chdir('/gpfs/data/abl/deepomics/tsirigoslab/histopathology/Repos/notebooks/')
plt.savefig('fig1c3.png', dpi=500, bbox_inches = 'tight')
# Out:
# /gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: This function is deprecated. Please call randint(0, 139 + 1) instead
# /gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:40: DeprecationWarning: This function is deprecated. Please call randint(0, 139 + 1) instead
# /gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:44: DeprecationWarning: This function is deprecated. Please call randint(0, 419 + 1) instead
# [0.         0.01351351 0.01515152 0.02702703 0.03030303 0.04054054
#  0.06060606 0.06756757 0.08108108 0.12121212 0.12162162 0.15151515
#  0.16216216 0.18181818 0.18918919 0.24242424 0.56060606 0.65151515
#  0.6969697  0.86363636 1.        ]
# {1: 0.9142096642096642, 2: 0.9711302211302211, 'micro': 0.9375510204081634, 'micro_cl': 0.9187047101449275, 'micro_cu': 0.9548557692307693, 'macro': 0.9504405147832665, 'macro_cl': 0.8842772439173994, 'macro_cu': 0.9873443559910186}

# %%
labels = label_binarize(labels, classes = [0, 1, 2])
fpr = dict()
tpr = dict()
roc_auc = dict()
label=labels 

### Individual class AUC ###
for i in [0, 1, 2]:
    fpr[i], tpr[i], _ = roc_curve(labels[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# /gpfs/share/apps/python/gpu/3.6.5/lib/python3.6/site-packages/sklearn/metrics/ranking.py:571: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
tpr
