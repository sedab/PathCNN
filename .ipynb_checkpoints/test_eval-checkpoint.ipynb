# %% [markdown]
# # evaluation functions

# %%
#libraries
import matplotlib
matplotlib.use('Agg')
#import torch
import numpy as np
from sklearn.metrics import roc_curve, auc, roc_auc_score, cohen_kappa_score, jaccard_similarity_score, log_loss,recall_score, precision_score
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
from PIL import Image
from utils.eval import *
from utils.dataloader import *
import os
from itertools import chain
import os.path
import json




# %matplotlib inline

# %% [markdown]
# ## evaluate single output file

# %%
experiments = '/gpfs/scratch/bilals01/test-repo/experiments/'
log_file = '/gpfs/scratch/bilals01/test-repo/logs/exp7_train.log'

exp_name = 'exp7'
num_class = 3


# Path to be created
os.mkdir( experiments + exp_name+ '/outputs/results/' );

pred_label = 'val_pred_label_avg_epoch_4.npy'

class_names, class_codes, class_coding = get_class_coding(log_file)
print(class_codes)
print(class_coding)

# %%
os.chdir(experiments + exp_name+ '/outputs/') #input
pd = np.load(open(pred_label, 'rb'))
predictions = pd[:,1:num_class+1] 
labels = pd[:,num_class+1]
predictions = np.asarray([[float(j) for j in i] for i in predictions])
labels = np.asarray([float(i) for i in labels])

# %%
#output 
#tpr; true positive rate
#fpr; false positive rate
#roc_auc; main eval metrics
#cu; upper confidence interval
#cl; lower confidence interval
fpr, tpr, roc_auc, cu, cl = get_auc(predictions, labels, class_names, class_codes)

os.chdir(experiments+exp_name+'/outputs/')
plt.savefig(pred_label[:-8]+'.png', dpi=500, bbox_inches = 'tight')

#create a data frame
results = {}
[class_coding,roc_auc,cu,cl ]
results['class_coding'] = class_coding
results['eval_metrics'] = roc_auc
results['cu'] = cu
results['cl'] = cl
results

#write to json
import json
with open(pred_label[:-8]+'_results.json', 'w') as outfile:
    json.dump(results, outfile)

#write true positive and false positive rates if needed
#import pickle
#filehandler = open(b"tpr_fpr.pkl","wb")
#pickle.dump([tpr,fpr],filehandler)
#filehandler.close()

# %% [markdown]
# ## evaluating multiple files

# %%
not os.path.exists(experiments + exp_name+ '/outputs/results/')
# Out:
# False

# %%
experiments = '/gpfs/scratch/bilals01/test-repo/experiments/'
log_file = '/gpfs/scratch/bilals01/test-repo/logs/exp7_train.log'

exp_name = 'exp7'
num_class = 3

# Path to be created
if not os.path.exists(experiments + exp_name+ '/outputs/results/'):
    os.mkdir( experiments + exp_name+ '/outputs/results/');

class_names, class_codes, class_coding = get_class_coding(log_file)
print(class_codes)
print(class_coding)
# Out:
# [0, 1, 2]
# {0: 'Solid_Tissue_Normal', 1: 'TCGA-LUAD', 2: 'TCGA-LUSC'}

# %%
import glob
path = experiments + exp_name+ '/outputs/'
files = [f for f in glob.glob(path + "**/*.npy", recursive=True)]

for f in files:
    ff = f.split('/')[-1].split('.')[0]
    print(ff)
    os.chdir(experiments + exp_name+ '/outputs/') #input
    pd = np.load(open(f, 'rb'))
    predictions = pd[:,1:num_class+1] 
    labels = pd[:,num_class+1]
    predictions = np.asarray([[float(j) for j in i] for i in predictions])
    labels = np.asarray([float(i) for i in labels])


    fpr, tpr, roc_auc, cu, cl = get_auc(predictions, labels, class_names, class_codes)

    os.chdir(experiments+exp_name+'/outputs/results/')
    #plt.savefig(pred_label[:-8]+'.png', dpi=500, bbox_inches = 'tight')

    #create a data frame
    results = {}
    [class_coding,roc_auc,cu,cl ]
    results['class_coding'] = class_coding
    results['eval_metrics'] = roc_auc
    results['cu'] = cu
    results['cl'] = cl
    results
   
    #write to json
    with open(ff+'_results.json', 'w') as outfile:
        json.dump(results, outfile)
# Out:
# val_pred_label_avg_epoch_2
# AUC:
# {0: 0.9881094612277408, 1: 0.9484649122807018, 2: 0.9467264127458302, 'micro': 0.9404700238727984, 'macro': 0.9629817794022628, 'precision': 0.8523344769020097, 'recall': 0.8184390317757716, 'cohenskappa': 0.706946540294003, 'jaccard': 0.8053691275167785, 'logloss': 0.5070364145968327}
# CU:
# {0: 0.9961136023916294, 1: 0.9676029962546817, 2: 0.9688460061443933, 'micro': 0.9527958662495324, 'macro': 0.9938508371385083}
# CL:
# {0: 0.9784699385741763, 1: 0.9264248704663212, 2: 0.9225453795379538, 'micro': 0.9286084294796326, 'macro': 0.9272118166590528}
# val_pred_label_avg_epoch_4
# AUC:
# {0: 0.9893610968879786, 1: 0.8894927536231884, 2: 0.9359721184963903, 'micro': 0.8981858925273637, 'macro': 0.9405244698982976, 'precision': 0.8062678062678064, 'recall': 0.7432820034023692, 'cohenskappa': 0.6028567523236741, 'jaccard': 0.738255033557047, 'logloss': 0.606709718039543}
# CU:
# {0: 0.9965257972517502, 1: 0.9204123910006262, 2: 0.9617027692616977, 'micro': 0.9148646749669767, 'macro': 0.9946521021789839}
# CL:
# {0: 0.980085348506401, 1: 0.8531579708050296, 2: 0.9091416679356378, 'micro': 0.8798718003687347, 'macro': 0.8677655677655678}
# val_pred_label_avg_epoch_3
# AUC:
# {0: 0.9870285031575354, 1: 0.9444126620900076, 2: 0.949614139905402, 'micro': 0.9515731273366065, 'macro': 0.9619720845918379, 'precision': 0.8635838506562278, 'recall': 0.8456590355187982, 'cohenskappa': 0.7470846841953389, 'jaccard': 0.8322147651006712, 'logloss': 0.46480039662125283}
# CU:
# {0: 0.9984518348623854, 1: 0.9628173550587343, 2: 0.9692714194842688, 'micro': 0.9618253791257805, 'macro': 0.996103896103896}
# CL:
# {0: 0.9707468540611212, 1: 0.9245073950956304, 2: 0.9277290448343081, 'micro': 0.9403606937935264, 'macro': 0.928763440860215}
# val_pred_label_avg_epoch_7
# AUC:
# {0: 0.9878818911076975, 1: 0.9430301296720061, 2: 0.9489668907144635, 'micro': 0.9521361650376109, 'macro': 0.9621989393013777, 'precision': 0.8679080265199605, 'recall': 0.8435888054067808, 'cohenskappa': 0.7466115674370355, 'jaccard': 0.8322147651006712, 'logloss': 0.4568670028919751}
# CU:
# {0: 0.9988532110091743, 1: 0.9641682785299807, 2: 0.9704569933835975, 'micro': 0.9636115482011629, 'macro': 0.9978949763896}
# CL:
# {0: 0.9697235629662131, 1: 0.9189760220125787, 2: 0.9256637168141593, 'micro': 0.9408566151004388, 'macro': 0.925185362353504}
# val_pred_label_avg_epoch_5
# AUC:
# {0: 0.9894179894179894, 1: 0.9317315026697177, 2: 0.9460293751555888, 'micro': 0.9437694248006846, 'macro': 0.957464655766094, 'precision': 0.8501072705054348, 'recall': 0.8250829038315555, 'cohenskappa': 0.7209595314707935, 'jaccard': 0.8154362416107382, 'logloss': 0.4737592032371003}
# CU:
# {0: 0.9984423676012462, 1: 0.953932584269663, 2: 0.9669874167283494, 'micro': 0.955124716553288, 'macro': 0.9969835907335908}
# CL:
# {0: 0.976203288490284, 1: 0.9064500941619585, 2: 0.9245073950956303, 'micro': 0.931358444981331, 'macro': 0.9157575757575758}
# val_pred_label_avg_epoch_6
# AUC:
# {0: 0.9882232462877624, 1: 0.9518497330282227, 2: 0.9591735125715708, 'micro': 0.9532678708166298, 'macro': 0.9680338632921258, 'precision': 0.8699536435504219, 'recall': 0.8485577782403991, 'cohenskappa': 0.7566560623330668, 'jaccard': 0.8389261744966443, 'logloss': 0.45800947192261726}
# CU:
# {0: 0.9984393965666725, 1: 0.9678846057194552, 2: 0.9762005949851253, 'micro': 0.9636628637483038, 'macro': 0.9972079171061612}
# CL:
# {0: 0.9719669383272643, 1: 0.9317866539105477, 2: 0.941123531640773, 'micro': 0.9425610658771282, 'macro': 0.9382613510520487}
# val_pred_label_avg_epoch_1
# AUC:
# {0: 0.9868009330374922, 1: 0.883056826849733, 2: 0.9081901916853372, 'micro': 0.9184721408945543, 'macro': 0.9280938270318158, 'precision': 0.8215495547812622, 'recall': 0.7881015916273965, 'cohenskappa': 0.6771064444559104, 'jaccard': 0.7885906040268457, 'logloss': 0.5886095535167609}
# CU:
# {0: 0.9961336647334991, 1: 0.9157392686804452, 2: 0.9398230088495575, 'micro': 0.9335350201686835, 'macro': 0.9939671814671814}
# CL:
# {0: 0.9741055430321948, 1: 0.8493461633358006, 2: 0.8766560073092736, 'micro': 0.9026823793490459, 'macro': 0.8614119922630561}

# %% [markdown]
# ## aggregate jsons

# %%
#os.chdir(experiments+exp_name+'/outputs/results/')
path = experiments+exp_name+'/outputs/results/'
res_files = [f for f in glob.glob(path + "**/*.json", recursive=True)]

for rf in res_files:
    with open(rf) as json_file:
        data = json.load(json_file)
        print(data['eval_metrics']['0'])
        print(data['eval_metrics']['1'])
        print(data['eval_metrics']['2'])
        print(data['eval_metrics']['micro'])
        print(data['eval_metrics']['macro'])
        print(data['eval_metrics']['precision'])
        print(data['eval_metrics']['recall'])
        print(data['eval_metrics']['cohenskappa'])
        print(data['eval_metrics']['jaccard'])
        print('______________________________')
        print(data['cu']['0'])
        print(data['cu']['1'])
        print(data['cu']['2'])
        print(data['cu']['micro'])
        print(data['cu']['macro'])
        print('______________________________')
        print(data['cl']['0'])
        print(data['cl']['1'])
        print(data['cl']['2'])
        print(data['cl']['micro'])
        print(data['cl']['macro'])
# Out:
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9868009330374922, '1': 0.883056826849733, '2': 0.9081901916853372, 'micro': 0.9184721408945543, 'macro': 0.9280938270318158, 'precision': 0.8215495547812622, 'recall': 0.7881015916273965, 'cohenskappa': 0.6771064444559104, 'jaccard': 0.7885906040268457, 'logloss': 0.5886095535167609}, 'cu': {'0': 0.9961336647334991, '1': 0.9157392686804452, '2': 0.9398230088495575, 'micro': 0.9335350201686835, 'macro': 0.9939671814671814}, 'cl': {'0': 0.9741055430321948, '1': 0.8493461633358006, '2': 0.8766560073092736, 'micro': 0.9026823793490459, 'macro': 0.8614119922630561}}
# 0.9868009330374922
# 0.883056826849733
# 0.9081901916853372
# 0.9184721408945543
# 0.9280938270318158
# 0.8215495547812622
# 0.7881015916273965
# 0.6771064444559104
# 0.7885906040268457
# ______________________________
# 0.9961336647334991
# 0.9157392686804452
# 0.9398230088495575
# 0.9335350201686835
# 0.9939671814671814
# ______________________________
# 0.9741055430321948
# 0.8493461633358006
# 0.8766560073092736
# 0.9026823793490459
# 0.8614119922630561
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9893610968879786, '1': 0.8894927536231884, '2': 0.9359721184963903, 'micro': 0.8981858925273637, 'macro': 0.9405244698982976, 'precision': 0.8062678062678064, 'recall': 0.7432820034023692, 'cohenskappa': 0.6028567523236741, 'jaccard': 0.738255033557047, 'logloss': 0.606709718039543}, 'cu': {'0': 0.9965257972517502, '1': 0.9204123910006262, '2': 0.9617027692616977, 'micro': 0.9148646749669767, 'macro': 0.9946521021789839}, 'cl': {'0': 0.980085348506401, '1': 0.8531579708050296, '2': 0.9091416679356378, 'micro': 0.8798718003687347, 'macro': 0.8677655677655678}}
# 0.9893610968879786
# 0.8894927536231884
# 0.9359721184963903
# 0.8981858925273637
# 0.9405244698982976
# 0.8062678062678064
# 0.7432820034023692
# 0.6028567523236741
# 0.738255033557047
# ______________________________
# 0.9965257972517502
# 0.9204123910006262
# 0.9617027692616977
# 0.9148646749669767
# 0.9946521021789839
# ______________________________
# 0.980085348506401
# 0.8531579708050296
# 0.9091416679356378
# 0.8798718003687347
# 0.8677655677655678
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9878818911076975, '1': 0.9430301296720061, '2': 0.9489668907144635, 'micro': 0.9521361650376109, 'macro': 0.9621989393013777, 'precision': 0.8679080265199605, 'recall': 0.8435888054067808, 'cohenskappa': 0.7466115674370355, 'jaccard': 0.8322147651006712, 'logloss': 0.4568670028919751}, 'cu': {'0': 0.9988532110091743, '1': 0.9641682785299807, '2': 0.9704569933835975, 'micro': 0.9636115482011629, 'macro': 0.9978949763896}, 'cl': {'0': 0.9697235629662131, '1': 0.9189760220125787, '2': 0.9256637168141593, 'micro': 0.9408566151004388, 'macro': 0.925185362353504}}
# 0.9878818911076975
# 0.9430301296720061
# 0.9489668907144635
# 0.9521361650376109
# 0.9621989393013777
# 0.8679080265199605
# 0.8435888054067808
# 0.7466115674370355
# 0.8322147651006712
# ______________________________
# 0.9988532110091743
# 0.9641682785299807
# 0.9704569933835975
# 0.9636115482011629
# 0.9978949763896
# ______________________________
# 0.9697235629662131
# 0.9189760220125787
# 0.9256637168141593
# 0.9408566151004388
# 0.925185362353504
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9894179894179894, '1': 0.9317315026697177, '2': 0.9460293751555888, 'micro': 0.9437694248006846, 'macro': 0.957464655766094, 'precision': 0.8501072705054348, 'recall': 0.8250829038315555, 'cohenskappa': 0.7209595314707935, 'jaccard': 0.8154362416107382, 'logloss': 0.4737592032371003}, 'cu': {'0': 0.9984423676012462, '1': 0.953932584269663, '2': 0.9669874167283494, 'micro': 0.955124716553288, 'macro': 0.9969835907335908}, 'cl': {'0': 0.976203288490284, '1': 0.9064500941619585, '2': 0.9245073950956303, 'micro': 0.931358444981331, 'macro': 0.9157575757575758}}
# 0.9894179894179894
# 0.9317315026697177
# 0.9460293751555888
# 0.9437694248006846
# 0.957464655766094
# 0.8501072705054348
# 0.8250829038315555
# 0.7209595314707935
# 0.8154362416107382
# ______________________________
# 0.9984423676012462
# 0.953932584269663
# 0.9669874167283494
# 0.955124716553288
# 0.9969835907335908
# ______________________________
# 0.976203288490284
# 0.9064500941619585
# 0.9245073950956303
# 0.931358444981331
# 0.9157575757575758
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9881094612277408, '1': 0.9484649122807018, '2': 0.9467264127458302, 'micro': 0.9404700238727984, 'macro': 0.9629817794022628, 'precision': 0.8523344769020097, 'recall': 0.8184390317757716, 'cohenskappa': 0.706946540294003, 'jaccard': 0.8053691275167785, 'logloss': 0.5070364145968327}, 'cu': {'0': 0.9961136023916294, '1': 0.9676029962546817, '2': 0.9688460061443933, 'micro': 0.9527958662495324, 'macro': 0.9938508371385083}, 'cl': {'0': 0.9784699385741763, '1': 0.9264248704663212, '2': 0.9225453795379538, 'micro': 0.9286084294796326, 'macro': 0.9272118166590528}}
# 0.9881094612277408
# 0.9484649122807018
# 0.9467264127458302
# 0.9404700238727984
# 0.9629817794022628
# 0.8523344769020097
# 0.8184390317757716
# 0.706946540294003
# 0.8053691275167785
# ______________________________
# 0.9961136023916294
# 0.9676029962546817
# 0.9688460061443933
# 0.9527958662495324
# 0.9938508371385083
# ______________________________
# 0.9784699385741763
# 0.9264248704663212
# 0.9225453795379538
# 0.9286084294796326
# 0.9272118166590528
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9882232462877624, '1': 0.9518497330282227, '2': 0.9591735125715708, 'micro': 0.9532678708166298, 'macro': 0.9680338632921258, 'precision': 0.8699536435504219, 'recall': 0.8485577782403991, 'cohenskappa': 0.7566560623330668, 'jaccard': 0.8389261744966443, 'logloss': 0.45800947192261726}, 'cu': {'0': 0.9984393965666725, '1': 0.9678846057194552, '2': 0.9762005949851253, 'micro': 0.9636628637483038, 'macro': 0.9972079171061612}, 'cl': {'0': 0.9719669383272643, '1': 0.9317866539105477, '2': 0.941123531640773, 'micro': 0.9425610658771282, 'macro': 0.9382613510520487}}
# 0.9882232462877624
# 0.9518497330282227
# 0.9591735125715708
# 0.9532678708166298
# 0.9680338632921258
# 0.8699536435504219
# 0.8485577782403991
# 0.7566560623330668
# 0.8389261744966443
# ______________________________
# 0.9984393965666725
# 0.9678846057194552
# 0.9762005949851253
# 0.9636628637483038
# 0.9972079171061612
# ______________________________
# 0.9719669383272643
# 0.9317866539105477
# 0.941123531640773
# 0.9425610658771282
# 0.9382613510520487
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9870285031575354, '1': 0.9444126620900076, '2': 0.949614139905402, 'micro': 0.9515731273366065, 'macro': 0.9619720845918379, 'precision': 0.8635838506562278, 'recall': 0.8456590355187982, 'cohenskappa': 0.7470846841953389, 'jaccard': 0.8322147651006712, 'logloss': 0.46480039662125283}, 'cu': {'0': 0.9984518348623854, '1': 0.9628173550587343, '2': 0.9692714194842688, 'micro': 0.9618253791257805, 'macro': 0.996103896103896}, 'cl': {'0': 0.9707468540611212, '1': 0.9245073950956304, '2': 0.9277290448343081, 'micro': 0.9403606937935264, 'macro': 0.928763440860215}}
# 0.9870285031575354
# 0.9444126620900076
# 0.949614139905402
# 0.9515731273366065
# 0.9619720845918379
# 0.8635838506562278
# 0.8456590355187982
# 0.7470846841953389
# 0.8322147651006712
# ______________________________
# 0.9984518348623854
# 0.9628173550587343
# 0.9692714194842688
# 0.9618253791257805
# 0.996103896103896
# ______________________________
# 0.9707468540611212
# 0.9245073950956304
# 0.9277290448343081
# 0.9403606937935264
# 0.928763440860215
# {'class_coding': {'0': 'Solid_Tissue_Normal', '1': 'TCGA-LUAD', '2': 'TCGA-LUSC'}, 'eval_metrics': {'0': 0.9868009330374922, '1': 0.883056826849733, '2': 0.9081901916853372, 'micro': 0.9184721408945543, 'macro': 0.9280938270318158, 'precision': 0.8215495547812622, 'recall': 0.7881015916273965, 'cohenskappa': 0.6771064444559104, 'jaccard': 0.7885906040268457, 'logloss': 0.5886095535167609}, 'cu': {'0': 0.9961336647334991, '1': 0.9157392686804452, '2': 0.9398230088495575, 'micro': 0.9335350201686835, 'macro': 0.9939671814671814}, 'cl': {'0': 0.9741055430321948, '1': 0.8493461633358006, '2': 0.8766560073092736, 'micro': 0.9026823793490459, 'macro': 0.8614119922630561}}
# 0.9868009330374922
# 0.883056826849733
# 0.9081901916853372
# 0.9184721408945543
# 0.9280938270318158
# 0.8215495547812622
# 0.7881015916273965
# 0.6771064444559104
# 0.7885906040268457
# ______________________________
# 0.9961336647334991
# 0.9157392686804452
# 0.9398230088495575
# 0.9335350201686835
# 0.9939671814671814
# ______________________________
# 0.9741055430321948
# 0.8493461633358006
# 0.8766560073092736
# 0.9026823793490459
# 0.8614119922630561
